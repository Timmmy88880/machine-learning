# %% [markdown]
# <a href="https://colab.research.google.com/github/Timmmy88880/machine-learning/blob/cola/%E6%A9%9F%E5%99%A8%E5%AD%B8%E7%BF%92%EF%BC%9A%E5%BB%BA%E7%AB%8B%E7%B7%9A%E6%80%A7%E8%BF%B4%E6%AD%B8%E8%B3%87%E6%96%99%E8%88%87%E9%A0%90%E6%B8%AC%EF%BC%81.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn import datasets

X,y = datasets.make_regression(n_samples=200,n_features=1,n_targets=1,noise=10)

plt.scatter(X,y,linewidths=0.1)
plt.show()

model = LinearRegression()

model.fit(X,y)

predict = model.predict(X[:200,:])

plt.plot(X,predict,c="red")
plt.scatter(X,y)
plt.show()
